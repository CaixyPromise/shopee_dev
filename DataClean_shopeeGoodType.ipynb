# %%
import json

# %%
with open('shopeeGoodsType.json', encoding = 'utf-8') as fp:
    value = json.loads(fp.read())

# %%
data = value['data']
print(data)
# Out:
# {'list': [{'id': 100017, 'name': 'Women Clothes', 'display_name': '女生衣著', 'parent_id': 0, 'has_active_children': True, 'has_children': True, 'children': [{'id': 100099, 'name': 'Tops', 'display_name': '上衣', 'parent_id': 100017, 'has_active_children': True, 'has_children': True, 'children': [{'id': 100350, 'name': 'Tanks & Camisoles', 'display_name': '細肩帶 / 繞頸背心', 'parent_id': 100099, 'has_active_children': False, 'has_children': False, 'children': [], 'region_setting': {'enable_size_chart': True, 'low_stock_value': 0, 'dimension_mandatory': False}, 'is_prohibit': False}, {'id': 100351, 'name': 'Tube Tops', 'display_name': '平口背心', 'parent_id': 100099, 'has_active_children': False, 'has_children': False, 'children': [], 'region_setting': {'enable_size_chart': True, 'low_stock_value': 0, 'dimension_mandatory': False}, 'is_prohibit': False}, {'id': 100352, 'name': 'T-shirts', 'display_name': 'T恤', 'parent_id': 100099, 'has_active_children': False, 'has_children': False, 'children': [], '
# ...
